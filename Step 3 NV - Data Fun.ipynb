# %%
import os
import io
import numpy as np
import pandas 
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import gnupg
import getpass
import re
import seaborn as sns
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
import shared_functions as sf
import cufflinks as cf
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import seaborn as sns
import sklearn.cluster as cluster
# Out:
# /usr/local/lib/python3.5/dist-packages/fuzzywuzzy/fuzz.py:35: UserWarning:
#
# Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning

# %%
# load the data
df = pd.read_csv('Gender Pay Gap.csv')

# %%
df.describe()
# Out:
#        Percent Difference in Mean Hourly Wage  \
# count                            10508.000000
# mean                                 0.142994
# std                                  0.151774
# min                                 -4.000000
# 25%                                  0.050000
# 50%                                  0.133000
# 75%                                  0.229000
# max                                  1.590000
#
#        Percent Difference in Median Hourly Wage  \
# count                              10508.000000
# mean                                   0.118014
# std                                    0.160984
# min                                   -1.965000
# 25%                                    0.007000
# 50%                                    0.093000
# 75%                                    0.210000
# max                                    3.200000
#
#        Percent Difference in Mean Bonus Received  \
# count                               10508.000000
# mean                                    0.076230
# std                                     8.350383
# min                                  -820.000000
# 25%                                     0.000000
# 50%                                     0.220000
# 75%                                     0.530000
# max                                    38.482000
#
#        Percent Difference in Median Bonus Received  \
# count                                 10508.000000
# mean                                     -0.215289
# std                                      14.026204
# min                                   -1206.950000
# 25%                                       0.000000
# 50%                                       0.050000
# 75%                                       0.380000
# max                                      38.482000
#
#        Percentage of Males that Received a Bonus  \
# count                               10508.000000
# mean                                    0.354349
# std                                     0.363251
# min                                     0.000000
# 25%                                     0.008000
# 50%                                     0.195500
# 75%                                     0.731250
# max                                     1.000000
#
#        Percentage of Females that Received a Bonus  \
# count                                 10508.000000
# mean                                      0.339619
# std                                       0.360298
# min                                       0.000000
# 25%                                       0.003000
# 50%                                       0.173000
# 75%                                       0.701000
# max                                       1.000000
#
#        Proportion of Males in Lower Quartile  \
# count                           10508.000000
# mean                                0.464107
# std                                 0.241382
# min                                 0.000000
# 25%                                 0.270000
# 50%                                 0.445000
# 75%                                 0.645000
# max                                 1.000000
#
#        Proportion of Females in Lower Quartile  \
# count                             10508.000000
# mean                                  0.535893
# std                                   0.241382
# min                                   0.000000
# 25%                                   0.355000
# 50%                                   0.555000
# 75%                                   0.730000
# max                                   1.000000
#
#        Proportion of Males in Lower Middle Quartile  \
# count                                  10508.000000
# mean                                       0.505806
# std                                        0.261023
# min                                        0.000000
# 25%                                        0.295000
# 50%                                        0.485000
# 75%                                        0.725000
# max                                        1.000000
#
#        Proportion of Females in Lower Middle Quartile  \
# count                                    10508.000000
# mean                                         0.494194
# std                                          0.261023
# min                                          0.000000
# 25%                                          0.275000
# 50%                                          0.515000
# 75%                                          0.705000
# max                                          1.000000
#
#        Proportion of Males in Upper Middle Quartile  \
# count                                  10508.000000
# mean                                       0.549386
# std                                        0.262353
# min                                        0.000000
# 25%                                        0.340000
# 50%                                        0.540000
# 75%                                        0.787250
# max                                        1.000000
#
#        Proportion of Females in Upper Middle Quartile  \
# count                                    10508.000000
# mean                                         0.450614
# std                                          0.262353
# min                                          0.000000
# 25%                                          0.212750
# 50%                                          0.460000
# 75%                                          0.660000
# max                                          1.000000
#
#        Proportion of Males in Top Quartile  \
# count                         10508.000000
# mean                              0.608361
# std                               0.244119
# min                               0.000000
# 25%                               0.415000
# 50%                               0.627000
# 75%                               0.829000
# max                               1.000000
#
#        Proportion of Females in Top Quartile
# count                           10508.000000
# mean                                0.391639
# std                                 0.244119
# min                                 0.000000
# 25%                                 0.171000
# 50%                                 0.373000
# 75%                                 0.585000
# max                                 1.000000

# %%
df['Postsector'] = df.Postcode.str[:1]

# %%
df.head()
# Out:
#                         Employer Name  \
# 0       Bryanston School,Incorporated
# 1  RED BAND CHEMICAL COMPANY, LIMITED
# 2                         118 LIMITED
# 3                   123 EMPLOYEES LTD
# 4                        1610 LIMITED
#
#                                              Address   Postcode  \
# 0  Bryanston House,\r\nBlandford,\r\nDorset,\r\nU...   DT11 0PX
# 1  19, Smith's Place,\r\nLeith Walk,\r\nEdinburgh...    EH6 8NU
# 2  Fusion Point,\r\nDumballs Road,\r\nCardiff,\r\...   CF10 5BF
# 3  34, Roundhay Road,\r\nLeeds,\r\nEngland,\r\nLS...  \rLS7 1AB
# 4  Hestercombe House,\r\nCheddon Fitzpaine,\r\nTa...  \rTA2 8LG
#
#    Percent Difference in Mean Hourly Wage  \
# 0                                   0.180
# 1                                   0.023
# 2                                   0.017
# 3                                   0.410
# 4                                  -0.220
#
#    Percent Difference in Median Hourly Wage  \
# 0                                     0.282
# 1                                    -0.027
# 2                                     0.028
# 3                                     0.360
# 4                                    -0.340
#
#    Percent Difference in Mean Bonus Received  \
# 0                                      0.000
# 1                                      0.150
# 2                                      0.131
# 3                                     -0.698
# 4                                     -0.470
#
#    Percent Difference in Median Bonus Received  \
# 0                                        0.000
# 1                                        0.375
# 2                                        0.136
# 3                                       -1.572
# 4                                       -0.670
#
#    Percentage of Males that Received a Bonus  \
# 0                                      0.000
# 1                                      0.156
# 2                                      0.700
# 3                                      0.500
# 4                                      0.250
#
#    Percentage of Females that Received a Bonus  \
# 0                                        0.000
# 1                                        0.667
# 2                                        0.570
# 3                                        0.735
# 4                                        0.750
#
#    Proportion of Males in Lower Quartile    ...      \
# 0                                  0.244    ...
# 1                                  0.203    ...
# 2                                  0.510    ...
# 3                                  0.000    ...
# 4                                  0.560    ...
#
#    Proportion of Males in Upper Middle Quartile  \
# 0                                         0.492
# 1                                         0.103
# 2                                         0.500
# 3                                         0.110
# 4                                         0.300
#
#    Proportion of Females in Upper Middle Quartile  \
# 0                                           0.508
# 1                                           0.897
# 2                                           0.500
# 3                                           0.890
# 4                                           0.700
#
#    Proportion of Males in Top Quartile  Proportion of Females in Top Quartile  \
# 0                                0.515                                  0.485
# 1                                0.181                                  0.819
# 2                                0.580                                  0.420
# 3                                0.230                                  0.770
# 4                                0.240                                  0.760
#
#                   Company Link To GPG Info  \
# 0   https://www.bryanston.co.uk/employment
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4  https://www.1610.org.uk/gender-pay-gap/
#
#                                 Responsible Person  Employer Size  \
# 0  Nick McRobb (Bursar and Clerk to the Governors)     500 to 999
# 1                  Philip Galt (Managing Director)     250 to 499
# 2                 Emma Crowe (VP, Human Resources)     500 to 999
# 3               Chloe Lines (Financial Controller)     250 to 499
# 4                            Tim Nightingale (CEO)     250 to 499
#
#                          Current Name Submitted After The Deadline Postsector
# 0       Bryanston School,Incorporated                        False          D
# 1  RED BAND CHEMICAL COMPANY, LIMITED                        False          E
# 2                         118 LIMITED                        False          C
# 3                   123 EMPLOYEES LTD                         True         \r
# 4                        1610 LIMITED                         True         \r
#
# [5 rows x 23 columns]

# %%
pd.head()
# Out:
# 0     DT11 0PX
# 1      EH6 8NU
# 2     CF10 5BF
# 3    \rLS7 1AB
# 4    \rTA2 8LG
# Name: Postcode, dtype: object

# %%
import shared_functions as sf

# %%
plot_box('Postcode','Percent Difference in Mean Hourly Wage')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-a3d5a8e8e955> in <module>()
# ----> 1 plot_box('Postcode','Percent Difference in Mean Hourly Wage')
#
# NameError: name 'plot_box' is not defined
